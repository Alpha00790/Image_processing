# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("images/Alpha.jpg")

# %%
# blur = cv2.GaussianBlur(img,(9,9),0)

# %%
plt.imshow(img),plt.title('Original')
plt.xticks([]),plt.yticks([])
# plt.subplot(121),plt.imshow(blur),plt.title('Averaging')
# plt.xticks([]),plt.yticks([])
# cv2.imwrite('images/Alpha.jpg',blur)
# plt.show()
# Out:
# (([], []), ([], []))

# %%
plt.subplot(121),plt.imshow(blur),plt.title('Averaging')
# Out:
# (<AxesSubplot:title={'center':'Averaging'}>,
#  <matplotlib.image.AxesImage at 0x203d872a6e0>,
#  Text(0.5, 1.0, 'Averaging'))
