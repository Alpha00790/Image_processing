# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
image = Image.open("images/Alpha.jpg")

# %%
img = cv2.imread("images/Alpha.jpg")

# %%
plt.imshow(img),plt.title('Original')
# Out:
# (<matplotlib.image.AxesImage at 0x1c3fce3a8c0>, Text(0.5, 1.0, 'Original'))

# %%
plt.show()

# %%
print(img)
# Out:
# [[[ 77  82  91]
#   [ 80  86  93]
#   [ 87  93  98]
#   ...
#   [ 16  23  32]
#   [ 20  22  32]
#   [ 20  22  32]]
#
#  [[ 76  81  90]
#   [ 78  84  91]
#   [ 84  90  95]
#   ...
#   [ 16  23  32]
#   [ 18  23  32]
#   [ 20  22  32]]
#
#  [[ 69  76  85]
#   [ 71  79  86]
#   [ 76  85  89]
#   ...
#   [ 16  23  32]
#   [ 18  24  31]
#   [ 18  24  31]]
#
#  ...
#
#  [[ 97 161 191]
#   [ 95 161 190]
#   [ 95 159 189]
#   ...
#   [ 21  23  24]
#   [ 24  23  25]
#   [ 24  23  25]]
#
#  [[ 98 162 187]
#   [ 95 161 186]
#   [ 96 159 187]
#   ...
#   [ 22  21  23]
#   [ 23  22  24]
#   [ 23  22  24]]
#
#  [[ 99 163 187]
#   [ 97 161 185]
#   [ 96 160 185]
#   ...
#   [ 22  21  23]
#   [ 23  22  24]
#   [ 23  22  24]]]

# %%
import random

# %%
def sp_noise(image,prob):
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else :
                output[i][j] = image[i][j]
    return output

# %%
image = Image.open("images/Alpha.jpg")

# %%
image = image.convert("L")

# %%
image.show()
print(image)
# Out:
# <PIL.Image.Image image mode=L size=6000x4000 at 0x1C3EC95E260>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('images/Alpha.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
print(img)
# Out:
# [[[ 91  82  77]
#   [ 93  86  80]
#   [ 98  93  87]
#   ...
#   [ 32  23  16]
#   [ 32  22  20]
#   [ 32  22  20]]
#
#  [[ 90  81  76]
#   [ 91  84  78]
#   [ 95  90  84]
#   ...
#   [ 32  23  16]
#   [ 32  23  18]
#   [ 32  22  20]]
#
#  [[ 85  76  69]
#   [ 86  79  71]
#   [ 89  85  76]
#   ...
#   [ 32  23  16]
#   [ 31  24  18]
#   [ 31  24  18]]
#
#  ...
#
#  [[191 161  97]
#   [190 161  95]
#   [189 159  95]
#   ...
#   [ 24  23  21]
#   [ 25  23  24]
#   [ 25  23  24]]
#
#  [[187 162  98]
#   [186 161  95]
#   [187 159  96]
#   ...
#   [ 23  21  22]
#   [ 24  22  23]
#   [ 24  22  23]]
#
#  [[187 163  99]
#   [185 161  97]
#   [185 160  96]
#   ...
#   [ 23  21  22]
#   [ 24  22  23]
#   [ 24  22  23]]]

# %%
print(image)
# Out:
# <PIL.Image.Image image mode=L size=6000x4000 at 0x1C3EC95E260>

# %%
print(img)
# Out:
# [[[ 91  82  77]
#   [ 93  86  80]
#   [ 98  93  87]
#   ...
#   [ 32  23  16]
#   [ 32  22  20]
#   [ 32  22  20]]
#
#  [[ 90  81  76]
#   [ 91  84  78]
#   [ 95  90  84]
#   ...
#   [ 32  23  16]
#   [ 32  23  18]
#   [ 32  22  20]]
#
#  [[ 85  76  69]
#   [ 86  79  71]
#   [ 89  85  76]
#   ...
#   [ 32  23  16]
#   [ 31  24  18]
#   [ 31  24  18]]
#
#  ...
#
#  [[191 161  97]
#   [190 161  95]
#   [189 159  95]
#   ...
#   [ 24  23  21]
#   [ 25  23  24]
#   [ 25  23  24]]
#
#  [[187 162  98]
#   [186 161  95]
#   [187 159  96]
#   ...
#   [ 23  21  22]
#   [ 24  22  23]
#   [ 24  22  23]]
#
#  [[187 163  99]
#   [185 161  97]
#   [185 160  96]
#   ...
#   [ 23  21  22]
#   [ 24  22  23]
#   [ 24  22  23]]]
